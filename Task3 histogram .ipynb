# %% [markdown]
# <a href="https://colab.research.google.com/github/taniadas0220/taniadas0220/blob/main/Task3%20histogram%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data visualization using Histogram
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv("Iris.csv")

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#summary statistics
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Histogram for Sepal Length

# %%
iris[['SepalLengthCm']].hist(bins=20 ,figsize = (10,7))
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>]], dtype=object)

# %%
#Histogram for Sepal Width

# %%
iris [['SepalWidthCm']].hist(bins=20, figsize= (10,7))
# Out:
# array([[<Axes: title={'center': 'SepalWidthCm'}>]], dtype=object)

# %%
#Histogram for Petal Length

# %%
iris [['PetalLengthCm']].hist(bins=20, figsize= (10,7))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}>]], dtype=object)

# %%
#Histogram for Petal Width

# %%
iris [['PetalWidthCm']].hist(bins=20, figsize= (10,7))
# Out:
# array([[<Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
sns.countplot(data=iris,x="Species",hue='SepalWidthCm')
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=iris,x="Species",hue='PetalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.countplot(data=iris,x="Species",hue='SepalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.countplot(data=iris,x="Species",hue='PetalWidthCm')
# Out:
# <Axes: xlabel='Species', ylabel='count'>
